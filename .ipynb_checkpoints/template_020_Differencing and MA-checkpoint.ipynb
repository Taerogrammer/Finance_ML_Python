# %% [markdown]
# # 차분(Differencing) 과 이동평균(MA) - Simple Trade Strategy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import yfinance as yf
import FinanceDataReader as fdr

# %% [markdown]
# ## Price difference (익일 종가 - 당일 종가)
#
# PriceDiff = (Close Price of tomorrow - Close Price of today)
#
# - shift(period)

# %%
fb = fdr.DataReader("META", start='20170809')
ms = fdr.DataReader("MSFT", start='20170809')
ms.head(2)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-08-09  72.250000  72.510002  72.050003  72.470001  66.951530  22213400
# 2017-08-10  71.900002  72.190002  71.349998  71.410004  65.972252  24734500

# %%
ms.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
fb.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
ms.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)

# %%
fb['Yesterday Close'] = fb['Close'].shift(1)   # default값 : 1
fb
# Out:
#                  Close  Yesterday Close
# Date
# 2017-08-09  171.179993              NaN
# 2017-08-10  167.399994       171.179993
# 2017-08-11  168.080002       167.399994
# 2017-08-14  170.750000       168.080002
# 2017-08-15  171.000000       170.750000
# ...                ...              ...
# 2024-02-05  459.410004       474.989990
# 2024-02-06  454.720001       459.410004
# 2024-02-07  469.589996       454.720001
# 2024-02-08  470.000000       469.589996
# 2024-02-09  468.109985       470.000000
#
# [1637 rows x 2 columns]

# %%
fb['Price Difference'] = fb['Close'] - fb['Yesterday Close']
fb['Price Diff2'] = fb['Close'].diff(1)   # 위의 식과 같은 의미
fb
# Out:
#                  Close  Yesterday Close  Price Difference  Price Diff2
# Date
# 2017-08-09  171.179993              NaN               NaN          NaN
# 2017-08-10  167.399994       171.179993         -3.779999    -3.779999
# 2017-08-11  168.080002       167.399994          0.680008     0.680008
# 2017-08-14  170.750000       168.080002          2.669998     2.669998
# 2017-08-15  171.000000       170.750000          0.250000     0.250000
# ...                ...              ...               ...          ...
# 2024-02-05  459.410004       474.989990        -15.579986   -15.579986
# 2024-02-06  454.720001       459.410004         -4.690003    -4.690003
# 2024-02-07  469.589996       454.720001         14.869995    14.869995
# 2024-02-08  470.000000       469.589996          0.410004     0.410004
# 2024-02-09  468.109985       470.000000         -1.890015    -1.890015
#
# [1637 rows x 4 columns]

# %% [markdown]
# Price Difference - manual 계산

# %%
ms['Yesterday Close'] = ms['Close'].shift(1)
ms['Price Difference'] = ms['Close'].diff()
ms.head()
# Out:
#                 Close  Yesterday Close  Price Difference
# Date
# 2017-08-09  72.470001              NaN               NaN
# 2017-08-10  71.410004        72.470001         -1.059997
# 2017-08-11  72.500000        71.410004          1.089996
# 2017-08-14  73.589996        72.500000          1.089996
# 2017-08-15  73.220001        73.589996         -0.369995

# %% [markdown]
# Price Difference - diff() method 사용

# %% [markdown]
# 차분한 값으로부터 원래의 값 복원하기

# %%
ms['Price Difference'].cumsum() + ms['Close']
# Out:
# Date
# 2017-08-09           NaN
# 2017-08-10     70.350007
# 2017-08-11     72.529999
# 2017-08-14     74.709991
# 2017-08-15     73.970001
#                  ...
# 2024-02-05    738.829987
# 2024-02-06    738.509979
# 2024-02-07    755.629975
# 2024-02-08    755.749969
# 2024-02-09    768.629975
# Length: 1637, dtype: float64

# %% [markdown]
# ## 일일 수익률 계산
#
# - 1 주를 계속 보유하였다고 가정.
#
#
# - 계산 방법.
#
# - Daily Return = df/df.shift(1) - 1
#     or
# - Daily Return[1:] = df[1:] / df[:-1].values - 1
#     or
# - Daily Return = df.pct_chage()

# %%
ms['Return'] = ms['Close'] / ms['Yesterday Close'] - 1
ms.head()
# Out:
#                 Close  Yesterday Close  Price Difference    Return
# Date
# 2017-08-09  72.470001              NaN               NaN       NaN
# 2017-08-10  71.410004        72.470001         -1.059997 -0.014627
# 2017-08-11  72.500000        71.410004          1.089996  0.015264
# 2017-08-14  73.589996        72.500000          1.089996  0.015034
# 2017-08-15  73.220001        73.589996         -0.369995 -0.005028

# %%
ms['Close'][1:] / ms['Close'][:-1].values - 1
# Out:
# Date
# 2017-08-10   -0.014627
# 2017-08-11    0.015264
# 2017-08-14    0.015034
# 2017-08-15   -0.005028
# 2017-08-16    0.005873
#                 ...
# 2024-02-05   -0.013545
# 2024-02-06   -0.000394
# 2024-02-07    0.021110
# 2024-02-08    0.000145
# 2024-02-09    0.015551
# Name: Close, Length: 1636, dtype: float64

# %%
ms['Close'].pct_change()
# Out:
# Date
# 2017-08-09         NaN
# 2017-08-10   -0.014627
# 2017-08-11    0.015264
# 2017-08-14    0.015034
# 2017-08-15   -0.005028
#                 ...
# 2024-02-05   -0.013545
# 2024-02-06   -0.000394
# 2024-02-07    0.021110
# 2024-02-08    0.000145
# 2024-02-09    0.015551
# Name: Close, Length: 1637, dtype: float64

# %%
len(pd.date_range(ms.index[0], ms.index[-1]))   # 날(day) 수
# Out:
# 2376

# %%
print(f"{len(pd.date_range(ms.index[0], ms.index[-1]))} 일간 1 주를 계속 보유하였다면 누적 수익율은")
print((1+ms['Return']).cumprod())
# Out:
# 2376 일간 1 주를 계속 보유하였다면 누적 수익율은
# Date
# 2017-08-09         NaN
# 2017-08-10    0.985373
# 2017-08-11    1.000414
# 2017-08-14    1.015455
# 2017-08-15    1.010349
#                 ...
# 2024-02-05    5.597488
# 2024-02-06    5.595281
# 2024-02-07    5.713398
# 2024-02-08    5.714226
# 2024-02-09    5.803091
# Name: Return, Length: 1637, dtype: float64

# %% [markdown]
# ## 이동평균 - Moving average
#
# - DataFrame.rolling()

# %%
# 3일 이동평균
(fb['Close'] + fb['Close'].shift(1) + fb['Close'].shift(2)) / 3
# Out:
# Date
# 2017-08-09           NaN
# 2017-08-10           NaN
# 2017-08-11    168.886663
# 2017-08-14    168.743332
# 2017-08-15    169.943334
#                  ...
# 2024-02-05    443.059998
# 2024-02-06    463.039998
# 2024-02-07    461.240000
# 2024-02-08    464.769999
# 2024-02-09    469.233327
# Name: Close, Length: 1637, dtype: float64

# %%
fb['Close'].rolling(3).mean()
# Out:
# Date
# 2017-08-09           NaN
# 2017-08-10           NaN
# 2017-08-11    168.886663
# 2017-08-14    168.743332
# 2017-08-15    169.943334
#                  ...
# 2024-02-05    443.059998
# 2024-02-06    463.039998
# 2024-02-07    461.240000
# 2024-02-08    464.769999
# 2024-02-09    469.233327
# Name: Close, Length: 1637, dtype: float64

# %% [markdown]
# ### 이동평균 계산 및 이동평균선 시각화

# %%
fb['ma30'] = fb['Close'].rolling(30).mean()
fb['ma60'] = fb['Close'].rolling(60).mean()#plot the moving average

#plot the moving average
plt.figure(figsize=(12, 6))
fb['ma30'].plot(label='MA30')
fb['ma60'].plot(label='MA60')
fb['Close'].plot(label='Close')
plt.legend()

# %%
fb.tail()
# Out:
#                  Close  Yesterday Close  Price Difference  Price Diff2  \
# Date
# 2024-02-05  459.410004       474.989990        -15.579986   -15.579986
# 2024-02-06  454.720001       459.410004         -4.690003    -4.690003
# 2024-02-07  469.589996       454.720001         14.869995    14.869995
# 2024-02-08  470.000000       469.589996          0.410004     0.410004
# 2024-02-09  468.109985       470.000000         -1.890015    -1.890015
#
#                   ma30        ma60
# Date
# 2024-02-05  377.126001  354.775667
# 2024-02-06  380.480335  357.024667
# 2024-02-07  384.353667  359.508667
# 2024-02-08  388.192668  361.862501
# 2024-02-09  391.868668  364.177834

# %%
plt.figure(figsize=(12, 6))
fb['Close'].loc['2022-01-01': '2022-03-31'].plot(label='close')
fb['ma60'].loc['2022-01-01': '2022-03-31'].plot(label='MA60')
fb['Close'].loc['2022-01-01': '2022-03-31'].plot(label='Close')
plt.legend()

# %% [markdown]
# ## EWMA (Exponentially-weighted moving average)
#
#
# SMA(Simple Moving Average)에는 몇 가지 "약점"이 있습니다.
# * window 가 작을수록 신호가 아닌 잡음이 증가합니다.
# * 항상 window 크기만큼 지연됩니다.
# * 평균화로 인해 데이터의 전체 피크 또는 계곡에 도달하지 않습니다.
# * 미래의 움직임에 대해 실제로 알려주지 않습니다. 실제로는 데이터의 trend를 묘사하는 것입니다.
# * 극단적인 historical value 로 인해 SMA가 크게 왜곡 될 수 있습니다.
#
# 이러한 문제를 해결하기 위해 EWMA (지수 가중 이동 평균)를 사용할 수 있습니다.

# %% [markdown]
# - EWMA를 사용하면 SMA의 지연 효과를 줄일 수 있으며 최근에 발생한 값에 더 많은 가중치를 적용합니다.
#
# - 가장 최근 값에 적용되는 가중치는 EWMA에 사용된 실제 매개 변수와 window 크기로 지정된 기간에 따라 다릅니다.
#
# EWMA 공식은 다음과 같습니다.
#
# $$ y_t =   \frac{\sum\limits_{i=0}^t w_i x_{t-i}}{\sum\limits_{i=0}^t w_i}$$
#
# $x_t$ 는 입력값, $w_i$ 는 적용된 weight (i=0 에서 t 사이로 변할 수 있음). $y_t$ 는 산출된 값입니다.

# %%
df = yf.download('AAPL', start='2020-01-01', end='2020-06-30', progress=False)
df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
df.head()
# Out:
#                 Close
# Date
# 2020-01-02  75.087502
# 2020-01-03  74.357498
# 2020-01-06  74.949997
# 2020-01-07  74.597504
# 2020-01-08  75.797501

# %%
df['ewma12'] = df['Close'].ewm(span=12).mean()
df['ewma30'] = df['Close'].ewm(span=30).mean()
df.plot(figsize=(12, 6))
# Out:
# <Axes: xlabel='Date'>
